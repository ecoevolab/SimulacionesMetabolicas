# %% [markdown]
# 11/21/25
#
# Para hacer gapfilling ya con un modelo borrador:
#
# for file in *.xml; do     base=$(basename "$file" .xml);     echo "Generando modelo para $base...";     gapfill "$file" -m LB -o "${base}_LB.xml"; done
#
# ✅✅✅

# %% [markdown]
# #!/bin/bash
# #SBATCH --job-name=carveme
# #SBATCH --output=%x.log
# #SBATCH --error=%x.error
# #SBATCH --time=240:00:00
# #SBATCH --cpus-per-task=8
# #SBATCH --mem=8G
#
# # Info del script
# date
# echo "===== Beginning CarveMe pipeline ====="
#
# # Activar ambiente conda
# eval "$(conda shell.bash hook)"
# module load anaconda3/2025.06
# source activate carveme-1.6.6
#
# # Directorios
# INPUT_DIR="/mnt/data/sur/users/mmontante/data/rizo_data/raw_data"
# OUTPUT_DIR="/mnt/data/sur/users/mmontante/data/rizo_data/carveme_prokka"
#
# mkdir -p "$OUTPUT_DIR"
#
# # Procesar archivos .faa (proteínas)
# echo "Reconstruyendo modelos"
# for file in "$INPUT_DIR"/*.faa; do
#
#     base=$(basename "$file" .faa)
#     echo "Modelo metabólico de: $base"
#
#     carve "$file" --gapfill LB \
#         --output "$OUTPUT_DIR/${base}.xml" \
#         || echo "Error procesando $base"
# done
#
# echo "Reconstruyendo modelo metabolico"
# for file in "$INPUT_DIR"/*.fna; do
#
#     base=$(basename "$file" .fna)
#     echo "Modelo metabólico para: $base"
#
#     carve --dna "$file" --gapfill LB \
#         --output "$OUTPUT_DIR/${base}.xml" \
#         || echo "Error procesando $base"
# done
#
# echo "===== Pipeline completado ====="
# date

# %% [markdown]
# Ejemplo sencillo de reconstruccion metabolica

# %%
import cometspy as c
import cobra.io
import os

# os.environ['COMETS_HOME'] = os.environ.get('COMETS_DIR', '')
csv_output_path = '/mnt/data/sur/users/mmontante/data/rizo_data/'

model_path = '/mnt/data/sur/users/mmontante/data/rizo_data/temp/ST00000.xml'
modelo = c.model(cobra.io.read_sbml_model(model_path))
test_tube = c.layout()
test_tube.add_model(modelo)

test_tube.set_specific_metabolite("h2o_e", 100)
test_tube.set_specific_metabolite("o2_e", 10)
test_tube.set_specific_metabolite("pi_e", 100)
test_tube.set_specific_metabolite("prbamp_e", 100)
test_tube.set_specific_metabolite("glu__L_e", 1)
test_tube.set_specific_metabolite("mn2_e", 100)
test_tube.set_specific_metabolite("gly_e", 1)
test_tube.set_specific_metabolite("zn2_e", 100)
test_tube.set_specific_metabolite("ala__L_e", 1)
test_tube.set_specific_metabolite("lys__L_e", 1)
test_tube.set_specific_metabolite("asp__L_e", 1)
test_tube.set_specific_metabolite("so4_e", 1)
test_tube.set_specific_metabolite("arg__L_e", 1)
test_tube.set_specific_metabolite("ser__L_e", 1)
test_tube.set_specific_metabolite("cu2_e", 1)
test_tube.set_specific_metabolite("met__L_e", 1)
test_tube.set_specific_metabolite("trp__L_e", 1)
test_tube.set_specific_metabolite("phe__L_e", 1)
test_tube.set_specific_metabolite("h_e", 1)
test_tube.set_specific_metabolite("tyr__L_e", 1)
test_tube.set_specific_metabolite("cys__L_e", 1)
test_tube.set_specific_metabolite("ura_e", 1)
test_tube.set_specific_metabolite("cl_e", 1)
test_tube.set_specific_metabolite("leu__L_e", 1) 
test_tube.set_specific_metabolite("his__L_e", 1)
test_tube.set_specific_metabolite("pro__L_e", 1)
test_tube.set_specific_metabolite("cobalt2_e", 100)
test_tube.set_specific_metabolite("val__L_e", 1)
test_tube.set_specific_metabolite("thr__L_e", 1)
test_tube.set_specific_metabolite("adn_e", 0.1)
test_tube.set_specific_metabolite("thymd_e", 0.1)
test_tube.set_specific_metabolite("k_e", 100)
test_tube.set_specific_metabolite("h2s_e", 0.1)
test_tube.set_specific_metabolite("ins_e", 0.1)
test_tube.set_specific_metabolite("uri_e", 0.1)
test_tube.set_specific_metabolite("mg2_e", 100)
test_tube.set_specific_metabolite("gsn_e", 0.1)
test_tube.set_specific_metabolite("ile__L_e", 1)
test_tube.set_specific_metabolite("skm_e", 1)
test_tube.set_specific_metabolite("fol_e", 1)
test_tube.set_specific_metabolite("dadn_e", 1)
test_tube.set_specific_metabolite("lipoate_e", 0.1)
test_tube.set_specific_metabolite("na1_e", 100)
test_tube.set_specific_metabolite("cd2_e", 100)
test_tube.set_specific_metabolite("aso4_e", 100)
test_tube.set_specific_metabolite("fe2_e", 100)
test_tube.set_specific_metabolite("fe3_e", 100)
test_tube.set_specific_metabolite("cro4_e", 100)
test_tube.set_specific_metabolite("nh3_c_e", 100)
test_tube.set_specific_metabolite("pheme_e", 100)
test_tube.set_specific_metabolite("cmp_e", 100)
test_tube.set_specific_metabolite("ump_e", 100)
test_tube.set_specific_metabolite("gmp_e", 100)
test_tube.set_specific_metabolite("pydx_e", 100)
test_tube.set_specific_metabolite("nac_e", 100)
test_tube.set_specific_metabolite("ribflv_e", 100)
test_tube.set_specific_metabolite("pphn_e", 100)
test_tube.set_specific_metabolite("hxan_e", 100)
test_tube.set_specific_metabolite("thmpp_e", 0.1)
test_tube.set_specific_metabolite("cbl1_e", 0.1)

trace_metabolites = ['ca2_e', 'cl_e', 'cobalt2_e', 'cu2_e', 'fe2_e', 'fe3_e', 'h_e', 'k_e', 'h2o_e', 'mg2_e',
                    'mn2_e', 'mobd_e', 'na1_e', 'ni2_e', 'nh4_e', 'o2_e', 'pi_e', 'so4_e', 'zn2_e']

for i in trace_metabolites:
    test_tube.set_specific_metabolite(i, 1000)
    test_tube.set_specific_static(i, 1000)

sim_params = c.params()
sim_params.set_param('maxCycles', 80)
sim_params.set_param('timeStep', 0.1)
experimet = c.comets(test_tube, sim_params)
experimet.run()

final_models = experimet.total_biomass
csv_file_name = os.path.join(csv_output_path, "ST00000_biomasa_8hrs.csv")
final_models.to_csv(csv_file_name, index=False)

# %%
import os

# Gurobi real (el importante)
os.environ['GUROBI_HOME'] = '/mnt/data/sur/modules/pkgs/mamba/main/envs/carveme'

# Para que cometspy no truene (dummy pero necesario)
os.environ['COMETS_HOME'] = os.environ['GUROBI_HOME']

# Librerías dinámicas
os.environ['LD_LIBRARY_PATH'] = (
    os.environ['GUROBI_HOME'] + '/lib:' +
    os.environ.get('LD_LIBRARY_PATH', '')
)

# %% [markdown]
# Ejemplo de mi jon python

# %% [markdown]
# #!/bin/bash
# #SBATCH --job-name=carveme_py
# #SBATCH --output=%x.log
# #SBATCH --error=%x.error
# #SBATCH --time=240:00:00
# #SBATCH --cpus-per-task=8
# #SBATCH --mem=8G
#
# date
# echo "===== Beginning CarveMe pipeline ====="
#
# # Activar ambiente conda
# eval "$(conda shell.bash hook)"
#
# # Ejecutar script de Python
# python /ruta/a/tu/script.py
#
# echo "===== Pipeline completado ====="
# date

# %%
# ------------------------------------------------------
# Genoma anotado en prokka y GEM recostruido en carveme
# ------------------------------------------------------
# Cargar paquetes 
# ------------------------------------------------------
import cometspy as c
import cobra.io
import pandas as pd
import matplotlib.pyplot as plt
import os
import glob
import numpy as np 
import csv
# -------------------------------------
# Cargar variables, rutas y parametros
# -------------------------------------
all_models = {} 
model_summary_data = []
sim_params = c.params()
sim_params.set_param('maxCycles', 160)
sim_params.set_param('timeStep', 0.1)

path_list = glob.glob('02_data/rizo/carveme/ST*_prokka_carveme_lb.xml')

initial_mass = [0, 0, 5e-8]   
csv_output_path = '04_resultados/rizo'
# -----------
# Ciclo for
# -----------
for model_path in path_list:
    
    file_name = os.path.basename(model_path)
    model_id = file_name.replace('.xml', '') 
    if '-draft' in file_name:
        continue
        
    try:          

        cobra_models = cobra.io.read_sbml_model(model_path)
        processed_models = c.model(cobra_models) 
        all_models[model_id] = processed_models

        processed_models.initial_pop = initial_mass
        test_tube = c.layout()
        test_tube.add_model(processed_models)
        test_tube.set_specific_metabolite("h2o_e", 100)
        test_tube.set_specific_metabolite("o2_e", 10)
        test_tube.set_specific_metabolite("pi_e", 100)
        test_tube.set_specific_metabolite("prbamp_e", 100)
        test_tube.set_specific_metabolite("glu__L_e", 1)
        test_tube.set_specific_metabolite("mn2_e", 100)
        test_tube.set_specific_metabolite("gly_e", 1)
        test_tube.set_specific_metabolite("zn2_e", 100)
        test_tube.set_specific_metabolite("ala__L_e", 1)
        test_tube.set_specific_metabolite("lys__L_e", 1)
        test_tube.set_specific_metabolite("asp__L_e", 1)
        test_tube.set_specific_metabolite("so4_e", 1)
        test_tube.set_specific_metabolite("arg__L_e", 1)
        test_tube.set_specific_metabolite("ser__L_e", 1)
        test_tube.set_specific_metabolite("cu2_e", 1)
        test_tube.set_specific_metabolite("met__L_e", 1)
        test_tube.set_specific_metabolite("trp__L_e", 1)
        test_tube.set_specific_metabolite("phe__L_e", 1)
        test_tube.set_specific_metabolite("h_e", 1)
        test_tube.set_specific_metabolite("tyr__L_e", 1)
        test_tube.set_specific_metabolite("cys__L_e", 1)
        test_tube.set_specific_metabolite("ura_e", 1)
        test_tube.set_specific_metabolite("cl_e", 1)
        test_tube.set_specific_metabolite("leu__L_e", 1) 
        test_tube.set_specific_metabolite("his__L_e", 1)
        test_tube.set_specific_metabolite("pro__L_e", 1)
        test_tube.set_specific_metabolite("cobalt2_e", 100)
        test_tube.set_specific_metabolite("val__L_e", 1)
        test_tube.set_specific_metabolite("thr__L_e", 1)
        test_tube.set_specific_metabolite("adn_e", 0.1)
        test_tube.set_specific_metabolite("thymd_e", 0.1)
        test_tube.set_specific_metabolite("k_e", 100)
        test_tube.set_specific_metabolite("h2s_e", 0.1)
        test_tube.set_specific_metabolite("ins_e", 0.1)
        test_tube.set_specific_metabolite("uri_e", 0.1)
        test_tube.set_specific_metabolite("mg2_e", 100)
        test_tube.set_specific_metabolite("gsn_e", 0.1)
        test_tube.set_specific_metabolite("ile__L_e", 1)
        test_tube.set_specific_metabolite("cys__L_e", 1)
        test_tube.set_specific_metabolite("skm_e", 1)
        test_tube.set_specific_metabolite("fol_e", 1)
        test_tube.set_specific_metabolite("dadn_e", 1)
        test_tube.set_specific_metabolite("lipoate_e", 0.1)
        test_tube.set_specific_metabolite("na1_e", 100)
        test_tube.set_specific_metabolite("cd2_e", 100)
        test_tube.set_specific_metabolite("aso4_e", 100)
        test_tube.set_specific_metabolite("fe2_e", 100)
        test_tube.set_specific_metabolite("fe3_e", 100)
        test_tube.set_specific_metabolite("cro4_e", 100)
        test_tube.set_specific_metabolite("nh3_c_e", 100)
        test_tube.set_specific_metabolite("pheme_e", 100)
        test_tube.set_specific_metabolite("cmp_e", 100)
        test_tube.set_specific_metabolite("ump_e", 100)
        test_tube.set_specific_metabolite("gmp_e", 100)
        test_tube.set_specific_metabolite("pydx_e", 100)
        test_tube.set_specific_metabolite("nac_e", 100)
        test_tube.set_specific_metabolite("ribflv_e", 100)
        test_tube.set_specific_metabolite("pphn_e", 100)
        test_tube.set_specific_metabolite("hxan_e", 100)
        test_tube.set_specific_metabolite("thmpp_e", 0.1)
        test_tube.set_specific_metabolite("cbl1_e", 0.1)


        trace_metabolites = ['ca2_e', 'cl_e', 'cobalt2_e', 'cu2_e', 'fe2_e', 'fe3_e', 'h_e', 'k_e', 'h2o_e', 'mg2_e',
                            'mn2_e', 'mobd_e', 'na1_e', 'ni2_e', 'nh4_e', 'o2_e', 'pi_e', 'so4_e', 'zn2_e']

        for i in trace_metabolites:
            test_tube.set_specific_metabolite(i, 1000)
            test_tube.set_specific_static(i, 1000)

        experimet = c.comets(test_tube, sim_params)
        experimet.run()
        final_models = experimet.total_biomass
        if final_models is not None:
            csv_file_name = os.path.join(csv_output_path, f"{model_id}_biomasa_8hrs.csv")
            final_models.to_csv(csv_file_name, index=False)
          

            print(f"archivo: {csv_file_name}, listo")
            print("========================================================")
            print(f"tabla biomasa: {model_id}, listo")
            print("========================================================")
            print(final_models.to_string())

    except Exception as e:
        print(f"Fallo en {model_id}: {e}.")

    finally:
        if final_models is None:
            print(f"error")

# %%
#!/bin/bash
 #SBATCH --job-name=prokka
 #SBATCH --output=%x.log
 #SBATCH --error=%x.error
 #SBATCH --time=240:00:00
 #SBATCH --cpus-per-task=8
 #SBATCH --mem=8G
  
 # Info del script
 # simulacion crecimiento individual 
date
echo "===== Beginning pipeline ====="
eval "$(mamba shell hook --shell bash)"
mamba activate python3
module load COMETS

python rizo_biomasa_prokka_carveme_lb_lb.py

# %%
import cometspy as c
import cobra.io
import pandas as pd
import matplotlib.pyplot as plt
import os
import glob
import numpy as np 
import csv
# -------------------------------------
all_models = {} 
model_summary_data = []
sim_params = c.params()
sim_params.set_param('maxCycles', 160)
sim_params.set_param('timeStep', 0.1)

path_list = glob.glob('/mnt/data/sur/users/mmontante/data/rizo_data/gem/ST*_prokka_carveme_lb.xml')

initial_mass = [0, 0, 5e-8]   
csv_output_path = '/mnt/data/sur/users/mmontante/data/rizo_data/resultados'

for model_path in path_list:
    
    file_name = os.path.basename(model_path)
    model_id = file_name.replace('.xml', '') 
    if '-draft' in file_name:
        continue
        
    try:          

        cobra_models = cobra.io.read_sbml_model(model_path)
        processed_models = c.model(cobra_models) 
        all_models[model_id] = processed_models

        processed_models.initial_pop = initial_mass
        test_tube = c.layout()
        test_tube.add_model(processed_models)
        test_tube.set_specific_metabolite("h2o_e", 100)
        test_tube.set_specific_metabolite("o2_e", 10)
        test_tube.set_specific_metabolite("pi_e", 100)
        test_tube.set_specific_metabolite("prbamp_e", 100)
        test_tube.set_specific_metabolite("glu__L_e", 1)
        test_tube.set_specific_metabolite("mn2_e", 100)
        test_tube.set_specific_metabolite("gly_e", 1)
        test_tube.set_specific_metabolite("zn2_e", 100)
        test_tube.set_specific_metabolite("ala__L_e", 1)
        test_tube.set_specific_metabolite("lys__L_e", 1)
        test_tube.set_specific_metabolite("asp__L_e", 1)
        test_tube.set_specific_metabolite("so4_e", 1)
        test_tube.set_specific_metabolite("arg__L_e", 1)
        test_tube.set_specific_metabolite("ser__L_e", 1)
        test_tube.set_specific_metabolite("cu2_e", 1)
        test_tube.set_specific_metabolite("met__L_e", 1)
        test_tube.set_specific_metabolite("trp__L_e", 1)
        test_tube.set_specific_metabolite("phe__L_e", 1)
        test_tube.set_specific_metabolite("h_e", 1)
        test_tube.set_specific_metabolite("tyr__L_e", 1)
        test_tube.set_specific_metabolite("cys__L_e", 1)
        test_tube.set_specific_metabolite("ura_e", 1)
        test_tube.set_specific_metabolite("cl_e", 1)
        test_tube.set_specific_metabolite("leu__L_e", 1) 
        test_tube.set_specific_metabolite("his__L_e", 1)
        test_tube.set_specific_metabolite("pro__L_e", 1)
        test_tube.set_specific_metabolite("cobalt2_e", 100)
        test_tube.set_specific_metabolite("val__L_e", 1)
        test_tube.set_specific_metabolite("thr__L_e", 1)
        test_tube.set_specific_metabolite("adn_e", 0.1)
        test_tube.set_specific_metabolite("thymd_e", 0.1)
        test_tube.set_specific_metabolite("k_e", 100)
        test_tube.set_specific_metabolite("h2s_e", 0.1)
        test_tube.set_specific_metabolite("ins_e", 0.1)
        test_tube.set_specific_metabolite("uri_e", 0.1)
        test_tube.set_specific_metabolite("mg2_e", 100)
        test_tube.set_specific_metabolite("gsn_e", 0.1)
        test_tube.set_specific_metabolite("ile__L_e", 1)
        test_tube.set_specific_metabolite("cys__L_e", 1)
        test_tube.set_specific_metabolite("skm_e", 1)
        test_tube.set_specific_metabolite("fol_e", 1)
        test_tube.set_specific_metabolite("dadn_e", 1)
        test_tube.set_specific_metabolite("lipoate_e", 0.1)
        test_tube.set_specific_metabolite("na1_e", 100)
        test_tube.set_specific_metabolite("cd2_e", 100)
        test_tube.set_specific_metabolite("aso4_e", 100)
        test_tube.set_specific_metabolite("fe2_e", 100)
        test_tube.set_specific_metabolite("fe3_e", 100)
        test_tube.set_specific_metabolite("cro4_e", 100)
        test_tube.set_specific_metabolite("nh3_c_e", 100)
        test_tube.set_specific_metabolite("pheme_e", 100)
        test_tube.set_specific_metabolite("cmp_e", 100)
        test_tube.set_specific_metabolite("ump_e", 100)
        test_tube.set_specific_metabolite("gmp_e", 100)
        test_tube.set_specific_metabolite("pydx_e", 100)
        test_tube.set_specific_metabolite("nac_e", 100)
        test_tube.set_specific_metabolite("ribflv_e", 100)
        test_tube.set_specific_metabolite("pphn_e", 100)
        test_tube.set_specific_metabolite("hxan_e", 100)
        test_tube.set_specific_metabolite("thmpp_e", 0.1)
        test_tube.set_specific_metabolite("cbl1_e", 0.1)


        trace_metabolites = ['ca2_e', 'cl_e', 'cobalt2_e', 'cu2_e', 'fe2_e', 'fe3_e', 'h_e', 'k_e', 'h2o_e', 'mg2_e',
                            'mn2_e', 'mobd_e', 'na1_e', 'ni2_e', 'nh4_e', 'o2_e', 'pi_e', 'so4_e', 'zn2_e']

        for i in trace_metabolites:
            test_tube.set_specific_metabolite(i, 1000)
            test_tube.set_specific_static(i, 1000)

        experimet = c.comets(test_tube, sim_params)
        experimet.run()
        final_models = experimet.total_biomass
        if final_models is not None:
            csv_file_name = os.path.join(csv_output_path, f"{model_id}_biomasa_8hrs.csv")
            final_models.to_csv(csv_file_name, index=False)
          

            print(f"archivo: {csv_file_name}, listo")
            print("========================================================")
            print(f"tabla biomasa: {model_id}, listo")
            print("========================================================")
            print(final_models.to_string())

    except Exception as e:
        print(f"Fallo en {model_id}: {e}.")

    finally:
        if final_models is None:
            print(f"error")

# %%
sshfs mmontante@fenix.lavis.unam.mx:/mnt/data/sur/users/mmontante/ /home/abigaylmontantearenas/Documents/proyecto_tesis/carpetaremota

# %%
import cometspy as c
import cobra.io
import pandas as pd
import matplotlib.pyplot as plt
import os
import glob
import numpy as np 
import csv
from pathlib import Path

# ---------------------------
all_models = {} 
model_summary_data = []
sim_params = c.params()
sim_params.set_param('maxCycles', 80)
initial_mass = [0, 0, 5e-8]   
csv_output_path = '/mnt/data/sur/users/mmontante/data/rizo_data/resultados/comunidades'


# ----------------------------------------------
def select_specific_files_os(folder_path, specific_filenames):

    selected_files = []
    
    for filename in specific_filenames:
        # os.path.join handles the correct slash for your OS
        full_path = os.path.join(folder_path, filename) 
        
        # Check if the file exists at that path
        if os.path.isfile(full_path):
            selected_files.append(full_path)
        else:
            print(f"Warning: '{filename}' not found.")
            
    return selected_files

# --- Example Usage ---
folder_location = "/mnt/data/sur/users/mmontante/data/rizo_data/resultados" 

comunidad_1 = ["ST00046_prokka_carveme_lb_24hr.xml", "ST00154_prokka_carveme_lb_24hr.xml"
                  , "ST00101_prokka_carveme_lb_24hr.xml", "ST00109_prokka_carveme_lb_24hr.xml", "ST00042_prokka_carveme_lb_24hr.xml"]

comunidad_2 = ["ST00046_prokka_carveme_lb_24hr.xml", "ST00154_prokka_carveme_lb_24hr.xml"
                  , "ST00101_prokka_carveme_lb_24hr.xml", "ST00109_prokka_carveme_lb_24hr.xml", "ST00060_prokka_carveme_lb_24hr.xml"]

comunidad_3 = ["ST00046_prokka_carveme_lb_24hr.xml", "ST00154_prokka_carveme_lb_24hr.xml"
                  , "ST00101_prokka_carveme_lb_24hr.xml", "ST00042_prokka_carveme_lb_24hr.xml", "ST00094_prokka_carveme_lb_24hr.xml"]

comunidad_4 = ["ST00046_prokka_carveme_lb_24hr.xml", "ST00154_prokka_carveme_lb_24hr.xml"
                  , "ST00109_prokka_carveme_lb_24hr.xml", "ST00042_prokka_carveme_lb_24hr.xml", "ST00110_prokka_carveme_lb_24hr.xml"]

comunidad_5 = ["ST00046_prokka_carveme_lb_24hr.xml", "ST00101_prokka_carveme_lb_24hr.xml"
                  , "ST00109_prokka_carveme_lb_24hr.xml", "ST00042_prokka_carveme_lb_24hr.xml", "ST00164_prokka_carveme_lb_24hr.xml"]

comunidad_6 = ["ST00154_prokka_carveme_lb_24hr.xml", "ST00101_prokka_carveme_lb_24hr.xml"
                  , "ST00109_prokka_carveme_lb_24hr.xml", "ST00042_prokka_carveme_lb_24hr.xml", "ST00164_prokka_carveme_lb_24hr.xml"]

#-------------------------------------------------

comunidad_7 = ["ST00060_prokka_carveme_lb_24hr.xml", "ST00094_prokka_carveme_lb_24hr.xml"
                 , "ST00110_prokka_carveme_lb_24hr.xml", "ST00164_prokka_carveme_lb_24hr.xml", "ST00143_prokka_carveme_lb_24hr.xml"]

comunidad_8 = ["ST00042_prokka_carveme_lb_24hr.xml", "ST00094_prokka_carveme_lb_24hr.xml"
                 , "ST00110_prokka_carveme_lb_24hr.xml", "ST00164_prokka_carveme_lb_24hr.xml", "ST00143_prokka_carveme_lb_24hr.xml"]

comunidad_9 = ["ST00109_prokka_carveme_lb_24hr.xml", "ST00060_prokka_carveme_lb_24hr.xml"
                 , "ST00110_prokka_carveme_lb_24hr.xml", "ST00164_prokka_carveme_lb_24hr.xml", "ST00143_prokka_carveme_lb_24hr.xml"]

comunidad_10 = ["ST00101_prokka_carveme_lb_24hr.xml", "ST00060_prokka_carveme_lb_24hr.xml"
                 , "ST00094_prokka_carveme_lb_24hr.xml", "ST00164_prokka_carveme_lb_24hr.xml", "ST00143_prokka_carveme_lb_24hr.xml"]

comunidad_11 = ["ST00154_prokka_carveme_lb_24hr.xml", "ST00060_prokka_carveme_lb_24hr.xml"
                 , "ST00094_prokka_carveme_lb_24hr.xml", "ST00110_prokka_carveme_lb_24hr.xml", "ST00164_prokka_carveme_lb_24hr.xml"]

comunidad_12 = ["ST00046_prokka_carveme_lb_24hr.xml", "ST00060_prokka_carveme_lb_24hr.xml"
                 , "ST00094_prokka_carveme_lb_24hr.xml", "ST00110_prokka_carveme_lb_24hr.xml", "ST00164_prokka_carveme_lb_24hr.xml"]

found_1 = select_specific_files_os(folder_location, comunidad_1)
found_2 = select_specific_files_os(folder_location, comunidad_2)
found_3 = select_specific_files_os(folder_location, comunidad_3)
found_4 = select_specific_files_os(folder_location, comunidad_4)
found_5 = select_specific_files_os(folder_location, comunidad_5)
found_6 = select_specific_files_os(folder_location, comunidad_6)
# --------------------------------------------------------------
found_7 = select_specific_files_os(folder_location, comunidad_7)
found_8 = select_specific_files_os(folder_location, comunidad_8)
found_9 = select_specific_files_os(folder_location, comunidad_9)
found_10 = select_specific_files_os(folder_location, comunidad_10)
found_11 = select_specific_files_os(folder_location, comunidad_11)
found_12 = select_specific_files_os(folder_location, comunidad_12)


comunidades = [found_1, found_2, found_3, found_4, found_5, found_6,found_7, found_8, found_9, found_10, found_11, found_12]

print("Found files (full paths):")

# -----------------------------------------------------------

for num, comunidad in enumerate(comunidades, start=8):
    test_tube = c.layout()

    try:
        # ----------------------------------------------------
        # Cargar todos los modelos de la comunidad
        for modelo in comunidad:
            file_name = os.path.basename(modelo)
            model_id = file_name.replace("_prokka_carveme_lb_24hr.xml", "")

            cobra_models = cobra.io.read_sbml_model(modelo)
            processed_models = c.model(cobra_models)

            processed_models.initial_pop = initial_mass
            test_tube.add_model(processed_models)

        # ----------------------------------------------------
        # Agregar metabolitos específicos (UNA sola vez)
        test_tube.set_specific_metabolite("h2o_e", 100)
        test_tube.set_specific_metabolite("o2_e", 10)
        test_tube.set_specific_metabolite("pi_e", 100)
        test_tube.set_specific_metabolite("prbamp_e", 100)
        test_tube.set_specific_metabolite("glu__L_e", 1)
        test_tube.set_specific_metabolite("mn2_e", 100)
        test_tube.set_specific_metabolite("gly_e", 1)
        test_tube.set_specific_metabolite("zn2_e", 100)
        test_tube.set_specific_metabolite("ala__L_e", 1)
        test_tube.set_specific_metabolite("lys__L_e", 1)
        test_tube.set_specific_metabolite("asp__L_e", 1)
        test_tube.set_specific_metabolite("so4_e", 1)
        test_tube.set_specific_metabolite("arg__L_e", 1)
        test_tube.set_specific_metabolite("ser__L_e", 1)
        test_tube.set_specific_metabolite("cu2_e", 1)
        test_tube.set_specific_metabolite("met__L_e", 1)
        test_tube.set_specific_metabolite("trp__L_e", 1)
        test_tube.set_specific_metabolite("phe__L_e", 1)
        test_tube.set_specific_metabolite("h_e", 1)
        test_tube.set_specific_metabolite("tyr__L_e", 1)
        test_tube.set_specific_metabolite("cys__L_e", 1)
        test_tube.set_specific_metabolite("ura_e", 1)
        test_tube.set_specific_metabolite("cl_e", 1)
        test_tube.set_specific_metabolite("leu__L_e", 1)
        test_tube.set_specific_metabolite("his__L_e", 1)
        test_tube.set_specific_metabolite("pro__L_e", 1)
        test_tube.set_specific_metabolite("cobalt2_e", 100)
        test_tube.set_specific_metabolite("val__L_e", 1)
        test_tube.set_specific_metabolite("thr__L_e", 1)
        test_tube.set_specific_metabolite("adn_e", 0.1)
        test_tube.set_specific_metabolite("thymd_e", 0.1)
        test_tube.set_specific_metabolite("k_e", 100)
        test_tube.set_specific_metabolite("h2s_e", 0.1)
        test_tube.set_specific_metabolite("ins_e", 0.1)
        test_tube.set_specific_metabolite("uri_e", 0.1)
        test_tube.set_specific_metabolite("mg2_e", 100)
        test_tube.set_specific_metabolite("gsn_e", 0.1)
        test_tube.set_specific_metabolite("ile__L_e", 1)
        test_tube.set_specific_metabolite("cys__L_e", 1)
        test_tube.set_specific_metabolite("skm_e", 1)
        test_tube.set_specific_metabolite("fol_e", 1)
        test_tube.set_specific_metabolite("dadn_e", 1)
        test_tube.set_specific_metabolite("lipoate_e", 0.1)
        test_tube.set_specific_metabolite("na1_e", 100)
        test_tube.set_specific_metabolite("cd2_e", 100)
        test_tube.set_specific_metabolite("aso4_e", 100)
        test_tube.set_specific_metabolite("fe2_e", 100)
        test_tube.set_specific_metabolite("fe3_e", 100)
        test_tube.set_specific_metabolite("cro4_e", 100)
        test_tube.set_specific_metabolite("nh3_c_e", 100)
        test_tube.set_specific_metabolite("pheme_e", 100)
        test_tube.set_specific_metabolite("cmp_e", 100)
        test_tube.set_specific_metabolite("ump_e", 100)
        test_tube.set_specific_metabolite("gmp_e", 100)
        test_tube.set_specific_metabolite("pydx_e", 100)
        test_tube.set_specific_metabolite("nac_e", 100)
        test_tube.set_specific_metabolite("ribflv_e", 100)
        test_tube.set_specific_metabolite("pphn_e", 100)
        test_tube.set_specific_metabolite("hxan_e", 100)
        test_tube.set_specific_metabolite("thmpp_e", 0.1)
        test_tube.set_specific_metabolite("cbl1_e", 0.1)

        # ----------------------------------------------------
        trace_metabolites = [
            'ca2_e', 'cl_e', 'cobalt2_e', 'cu2_e', 'fe2_e', 'fe3_e',
            'h_e', 'k_e', 'h2o_e', 'mg2_e', 'mn2_e', 'mobd_e',
            'na1_e', 'ni2_e', 'nh4_e', 'o2_e', 'pi_e', 'so4_e', 'zn2_e'
        ]

        for i in trace_metabolites:
            test_tube.set_specific_metabolite(i, 1000)
            test_tube.set_specific_static(i, 1000)

        # ----------------------------------------------------
        experimet = c.comets(test_tube, sim_params)
        experimet.run()

        final_models = experimet.total_biomass

        if final_models is not None:
            csv_file_name = os.path.join(csv_output_path, f"comunidad_{num}.csv")
            final_models.to_csv(csv_file_name, index=False)

            print(f" {num} registrada")
            print(final_models.to_string())
        else:
            print(f"{num} falló")

    except Exception as e:
        print(f"Falló {num}: {e}")

    finally:
        if final_models is None:
            print("ALLO DE SIMULACIÓN")

# %%
import cometspy as c
import cobra.io
import pandas as pd
import os
import glob
import numpy as np 
import csv
from pathlib import Path

# ---------------------------

final_models = {}
sim_params = c.params()
sim_params.set_param('maxCycles', 80)
initial_mass = [0, 0, 5e-8]   
csv_output_path = '/mnt/data/sur/users/mmontante/data/rizo_data/resultados/comunidades'


# ----------------------------------------------
def select_specific_files_os(folder_path, specific_filenames):

    selected_files = []
    
    for filename in specific_filenames:
        # os.path.join handles the correct slash for your OS
        full_path = os.path.join(folder_path, filename) 
        
        # Check if the file exists at that path
        if os.path.isfile(full_path):
            selected_files.append(full_path)
        else:
            print(f"Warning: '{filename}' not found.")
            
    return selected_files

folder_location = "/mnt/data/sur/users/mmontante/data/rizo_data/resultados" 
comunidad_1 = [
    "ST00046_prokka_carveme_lb_24hr.xml", "ST00154_prokka_carveme_lb_24hr.xml",
    "ST00101_prokka_carveme_lb_24hr.xml", "ST00109_prokka_carveme_lb_24hr.xml", 
    "ST00042_prokka_carveme_lb_24hr.xml"
]

comunidad_2 = [
    "ST00046_prokka_carveme_lb_24hr.xml", "ST00154_prokka_carveme_lb_24hr.xml",
    "ST00101_prokka_carveme_lb_24hr.xml", "ST00109_prokka_carveme_lb_24hr.xml", 
    "ST00060_prokka_carveme_lb_24hr.xml"
]

comunidad_3 = [
    "ST00046_prokka_carveme_lb_24hr.xml", "ST00154_prokka_carveme_lb_24hr.xml",
    "ST00101_prokka_carveme_lb_24hr.xml", "ST00042_prokka_carveme_lb_24hr.xml", 
    "ST00094_prokka_carveme_lb_24hr.xml"
]

found_1 = select_specific_files_os(folder_location, comunidad_1)
found_2 = select_specific_files_os(folder_location, comunidad_2)
found_3 = select_specific_files_os(folder_location, comunidad_3)

comunidades = [found_1, found_2, found_3]

print("Found files (full paths):")

# -----------------------------------------------------------
for num, comunidad in enumerate(comunidades, start=1): # start=1 para comunidad_1, 2, 3
    test_tube = c.layout()
    final_biomass_df = None # Variable de control para esta iteración

    try:
        # Cargar todos los modelos de la comunidad
        for modelo in comunidad:
            cobra_model = cobra.io.read_sbml_model(modelo)
            processed_model = c.model(cobra_model)
            processed_model.initial_pop = initial_mass
            test_tube.add_model(processed_model)

        # ----------------------------------------------------
        # Agregar metabolitos específicos (UNA sola vez)
        test_tube.set_specific_metabolite("h2o_e", 100)
        test_tube.set_specific_metabolite("o2_e", 10)
        test_tube.set_specific_metabolite("pi_e", 100)
        test_tube.set_specific_metabolite("prbamp_e", 100)
        test_tube.set_specific_metabolite("glu__L_e", 1)
        test_tube.set_specific_metabolite("mn2_e", 100)
        test_tube.set_specific_metabolite("gly_e", 1)
        test_tube.set_specific_metabolite("zn2_e", 100)
        test_tube.set_specific_metabolite("ala__L_e", 1)
        test_tube.set_specific_metabolite("lys__L_e", 1)
        test_tube.set_specific_metabolite("asp__L_e", 1)
        test_tube.set_specific_metabolite("so4_e", 1)
        test_tube.set_specific_metabolite("arg__L_e", 1)
        test_tube.set_specific_metabolite("ser__L_e", 1)
        test_tube.set_specific_metabolite("cu2_e", 1)
        test_tube.set_specific_metabolite("met__L_e", 1)
        test_tube.set_specific_metabolite("trp__L_e", 1)
        test_tube.set_specific_metabolite("phe__L_e", 1)
        test_tube.set_specific_metabolite("h_e", 1)
        test_tube.set_specific_metabolite("tyr__L_e", 1)
        test_tube.set_specific_metabolite("cys__L_e", 1)
        test_tube.set_specific_metabolite("ura_e", 1)
        test_tube.set_specific_metabolite("cl_e", 1)
        test_tube.set_specific_metabolite("leu__L_e", 1)
        test_tube.set_specific_metabolite("his__L_e", 1)
        test_tube.set_specific_metabolite("pro__L_e", 1)
        test_tube.set_specific_metabolite("cobalt2_e", 100)
        test_tube.set_specific_metabolite("val__L_e", 1)
        test_tube.set_specific_metabolite("thr__L_e", 1)
        test_tube.set_specific_metabolite("adn_e", 0.1)
        test_tube.set_specific_metabolite("thymd_e", 0.1)
        test_tube.set_specific_metabolite("k_e", 100)
        test_tube.set_specific_metabolite("h2s_e", 0.1)
        test_tube.set_specific_metabolite("ins_e", 0.1)
        test_tube.set_specific_metabolite("uri_e", 0.1)
        test_tube.set_specific_metabolite("mg2_e", 100)
        test_tube.set_specific_metabolite("gsn_e", 0.1)
        test_tube.set_specific_metabolite("ile__L_e", 1)
        test_tube.set_specific_metabolite("cys__L_e", 1)
        test_tube.set_specific_metabolite("skm_e", 1)
        test_tube.set_specific_metabolite("fol_e", 1)
        test_tube.set_specific_metabolite("dadn_e", 1)
        test_tube.set_specific_metabolite("lipoate_e", 0.1)
        test_tube.set_specific_metabolite("na1_e", 100)
        test_tube.set_specific_metabolite("cd2_e", 100)
        test_tube.set_specific_metabolite("aso4_e", 100)
        test_tube.set_specific_metabolite("fe2_e", 100)
        test_tube.set_specific_metabolite("fe3_e", 100)
        test_tube.set_specific_metabolite("cro4_e", 100)
        test_tube.set_specific_metabolite("nh3_c_e", 100)
        test_tube.set_specific_metabolite("pheme_e", 100)
        test_tube.set_specific_metabolite("cmp_e", 100)
        test_tube.set_specific_metabolite("ump_e", 100)
        test_tube.set_specific_metabolite("gmp_e", 100)
        test_tube.set_specific_metabolite("pydx_e", 100)
        test_tube.set_specific_metabolite("nac_e", 100)
        test_tube.set_specific_metabolite("ribflv_e", 100)
        test_tube.set_specific_metabolite("pphn_e", 100)
        test_tube.set_specific_metabolite("hxan_e", 100)
        test_tube.set_specific_metabolite("thmpp_e", 0.1)
        test_tube.set_specific_metabolite("cbl1_e", 0.1)

        # ----------------------------------------------------
        trace_metabolites = [
            'ca2_e', 'cl_e', 'cobalt2_e', 'cu2_e', 'fe2_e', 'fe3_e',
            'h_e', 'k_e', 'h2o_e', 'mg2_e', 'mn2_e', 'mobd_e',
            'na1_e', 'ni2_e', 'nh4_e', 'o2_e', 'pi_e', 'so4_e', 'zn2_e'
        ]

        for i in trace_metabolites:
            test_tube.set_specific_metabolite(i, 1000)
            test_tube.set_specific_static(i, 1000)

        # ----------------------------------------------------
        experiment = c.comets(test_tube, sim_params) # Asegúrate de escribirlo igual
        experiment.run()

        # Extraer resultados usando el mismo nombre de objeto
        final_biomass_df = experiment.total_biomass

        if final_biomass_df is not None:
            final_models[num] = final_biomass_df.copy() # Guarda en el dict global
            csv_file_name = os.path.join(csv_output_path, f"comunidad_{num}.csv")
            final_biomass_df.to_csv(csv_file_name, index=False)
            print(f"Comunidad {num} registrada exitosamente.")

# %%
#!/bin/bash
 #SBATCH --job-name=prokka
 #SBATCH --output=%x.log
 #SBATCH --error=%x.error
 #SBATCH --time=240:00:00
 #SBATCH --cpus-per-task=8
 #SBATCH --mem=8G
  
 # Info del script
 # prueba de prokka
 date
 echo "===== Beginning pipeline ====="
eval "$(mamba shell hook --shell bash)"
mamba activate python3
module load COMETS
 # comand line 


python rizo_comunidades_biomasa_prokka_carveme_lb.py 


 echo "===== Pipeline done ====="
 date

# %%
import cometspy as c
import cobra.io
import pandas as pd
import os
import glob
import numpy as np
import csv


# -------------------------------------
all_models = {} 
model_summary_data = []
sim_params = c.params()
sim_params.set_param('maxCycles', 160)
sim_params.set_param('timeStep', 0.1)

path_list = glob.glob('/mnt/data/sur/users/mmontante/data/rizo_data/gem/ST*_prokka_carveme_lb.xml')

initial_mass = [0, 0, 5e-8]   
csv_output_path = '/mnt/data/sur/users/mmontante/data/rizo_data/resultados'

for model_path in path_list:
    
    file_name = os.path.basename(model_path)
    model_id = file_name.replace('.xml', '') 
    if '-draft' in file_name:
        continue
        
    try:          

        cobra_models = cobra.io.read_sbml_model(model_path)
        processed_models = c.model(cobra_models) 
        all_models[model_id] = processed_models

        processed_models.initial_pop = initial_mass
        test_tube = c.layout()
        test_tube.add_model(processed_models)
        test_tube.set_specific_metabolite("h2o_e", 10.0)
        test_tube.set_specific_metabolite("o2_e", 1.0)
        test_tube.set_specific_metabolite("pi_e", 10.0)
        test_tube.set_specific_metabolite("prbamp_e", 10.0)
        test_tube.set_specific_metabolite("glu__L_e", 0.1)
        test_tube.set_specific_metabolite("mn2_e", 10.0)
        test_tube.set_specific_metabolite("gly_e", 0.1)
        test_tube.set_specific_metabolite("zn2_e", 10.0)
        test_tube.set_specific_metabolite("ala__L_e", 0.1)
        test_tube.set_specific_metabolite("lys__L_e", 0.1)
        test_tube.set_specific_metabolite("asp__L_e", 0.1)
        test_tube.set_specific_metabolite("so4_e", 0.1)
        test_tube.set_specific_metabolite("arg__L_e", 0.1)
        test_tube.set_specific_metabolite("ser__L_e", 0.1)
        test_tube.set_specific_metabolite("cu2_e", 0.1)
        test_tube.set_specific_metabolite("met__L_e", 0.1)
        test_tube.set_specific_metabolite("trp__L_e", 0.1)
        test_tube.set_specific_metabolite("phe__L_e", 0.1)
        test_tube.set_specific_metabolite("h_e", 0.1)
        test_tube.set_specific_metabolite("tyr__L_e", 0.1)
        test_tube.set_specific_metabolite("cys__L_e", 0.1)
        test_tube.set_specific_metabolite("ura_e", 0.1)
        test_tube.set_specific_metabolite("cl_e", 0.1)
        test_tube.set_specific_metabolite("leu__L_e", 0.1)
        test_tube.set_specific_metabolite("his__L_e", 0.1)
        test_tube.set_specific_metabolite("pro__L_e", 0.1)
        test_tube.set_specific_metabolite("cobalt2_e", 10.0)
        test_tube.set_specific_metabolite("val__L_e", 0.1)
        test_tube.set_specific_metabolite("thr__L_e", 0.1)
        test_tube.set_specific_metabolite("adn_e", 0.01)
        test_tube.set_specific_metabolite("thymd_e", 0.01)
        test_tube.set_specific_metabolite("k_e", 10.0)
        test_tube.set_specific_metabolite("h2s_e", 0.01)
        test_tube.set_specific_metabolite("ins_e", 0.01)
        test_tube.set_specific_metabolite("uri_e", 0.01)
        test_tube.set_specific_metabolite("mg2_e", 10.0)
        test_tube.set_specific_metabolite("gsn_e", 0.01)
        test_tube.set_specific_metabolite("ile__L_e", 0.1)
        test_tube.set_specific_metabolite("cys__L_e", 0.1)
        test_tube.set_specific_metabolite("skm_e", 0.1)
        test_tube.set_specific_metabolite("fol_e", 0.1)
        test_tube.set_specific_metabolite("dadn_e", 0.1)
        test_tube.set_specific_metabolite("lipoate_e", 0.01)
        test_tube.set_specific_metabolite("na1_e", 10.0)
        test_tube.set_specific_metabolite("cd2_e", 10.0)
        test_tube.set_specific_metabolite("aso4_e", 10.0)
        test_tube.set_specific_metabolite("fe2_e", 10.0)
        test_tube.set_specific_metabolite("fe3_e", 10.0)
        test_tube.set_specific_metabolite("cro4_e", 10.0)
        test_tube.set_specific_metabolite("nh3_c_e", 10.0)
        test_tube.set_specific_metabolite("pheme_e", 10.0)
        test_tube.set_specific_metabolite("cmp_e", 10.0)
        test_tube.set_specific_metabolite("ump_e", 10.0)
        test_tube.set_specific_metabolite("gmp_e", 10.0)
        test_tube.set_specific_metabolite("pydx_e", 10.0)
        test_tube.set_specific_metabolite("nac_e", 10.0)
        test_tube.set_specific_metabolite("ribflv_e", 10.0)
        test_tube.set_specific_metabolite("pphn_e", 10.0)
        test_tube.set_specific_metabolite("hxan_e", 10.0)
        test_tube.set_specific_metabolite("thmpp_e", 0.01)
        test_tube.set_specific_metabolite("cbl1_e", 0.01)

        trace_metabolites = ['ca2_e', 'cl_e', 'cobalt2_e', 'cu2_e', 'fe2_e', 'fe3_e', 'h_e', 'k_e', 'h2o_e', 'mg2_e',
                            'mn2_e', 'mobd_e', 'na1_e', 'ni2_e', 'nh4_e', 'o2_e', 'pi_e', 'so4_e', 'zn2_e']

        for i in trace_metabolites:
            test_tube.set_specific_metabolite(i, 1000)
            test_tube.set_specific_static(i, 1000)

        experimet = c.comets(test_tube, sim_params)
        experimet.run()
        final_models = experimet.total_biomass
        if final_models is not None:
            csv_file_name = os.path.join(csv_output_path, f"{model_id}_biomasa_16hrs.csv")
            final_models.to_csv(csv_file_name, index=False)
          

            print(f"archivo: {csv_file_name}, listo")
            print("========================================================")
            print(f"tabla biomasa: {model_id}, listo")
            print("========================================================")
            print(final_models.to_string())

    except Exception as e:
        print(f"Fallo en {model_id}: {e}.")

    finally:
        if final_models is None:
            print(f"error")

# %%
import cometspy as c
import cobra.io
import pandas as pd
import os

# ---------------------------
all_models = {} 
model_summary_data = []
sim_params = c.params()
sim_params.set_param('maxCycles', 80)
sim_params.set_param('timeStep', 0.1)
initial_mass = [0, 0, 5e-8]   
csv_output_path = '04_resultados/rizo/biomasas/'


# ----------------------------------------------
def select_specific_files_os(folder_path, specific_filenames):

    selected_files = []
    
    for filename in specific_filenames:
        # os.path.join handles the correct slash for your OS
        full_path = os.path.join(folder_path, filename) 
        
        # Check if the file exists at that path
        if os.path.isfile(full_path):
            selected_files.append(full_path)
        else:
            print(f"Warning: '{filename}' not found.")
            
    return selected_files

folder_location = "./02_data/rizo/carveme" 

comunidad_1 = ["ST00046_prokka_carveme_lb_24.xml", "ST00154_prokka_carveme_lb_24.xml", 
               "ST00101_prokka_carveme_lb_24.xml", "ST00109_prokka_carveme_lb_24.xml", 
               "ST00042_prokka_carveme_lb_24.xml"]

comunidad_2 = ["ST00046_prokka_carveme_lb_24.xml", "ST00154_prokka_carveme_lb_24.xml", 
               "ST00101_prokka_carveme_lb_24.xml", "ST00109_prokka_carveme_lb_24.xml", 
               "ST00060_prokka_carveme_lb_24.xml"]

comunidad_3 = ["ST00046_prokka_carveme_lb_24.xml", "ST00154_prokka_carveme_lb_24.xml", 
               "ST00101_prokka_carveme_lb_24.xml", "ST00042_prokka_carveme_lb_24.xml", 
               "ST00094_prokka_carveme_lb_24.xml"]


# #-------------------------------------------------


found_1 = select_specific_files_os(folder_location, comunidad_1)
found_2 = select_specific_files_os(folder_location, comunidad_2)
found_3 = select_specific_files_os(folder_location, comunidad_3)



comunidades = [found_1, found_2, found_3]

print("Found files (full paths):")

# -----------------------------------------------------------

for num, comunidad in enumerate(comunidades, start=1):
    test_tube = c.layout()

    try:
        # ----------------------------------------------------
        # Cargar todos los modelos de la comunidad
        for modelo in comunidad:
            file_name = os.path.basename(modelo)
            model_id = file_name.replace("_prokka_carveme_lb_24hr.xml", "")

            cobra_models = cobra.io.read_sbml_model(modelo)
            processed_models = c.model(cobra_models)

            processed_models.initial_pop = initial_mass
            test_tube.add_model(processed_models)

        # ----------------------------------------------------
        # Agregar metabolitos específicos (UNA sola vez)
        test_tube.set_specific_metabolite("h2o_e", 100)
        test_tube.set_specific_metabolite("o2_e", 10)
        test_tube.set_specific_metabolite("pi_e", 100)
        test_tube.set_specific_metabolite("prbamp_e", 100)
        test_tube.set_specific_metabolite("glu__L_e", 1)
        test_tube.set_specific_metabolite("mn2_e", 100)
        test_tube.set_specific_metabolite("gly_e", 1)
        test_tube.set_specific_metabolite("zn2_e", 100)
        test_tube.set_specific_metabolite("ala__L_e", 1)
        test_tube.set_specific_metabolite("lys__L_e", 1)
        test_tube.set_specific_metabolite("asp__L_e", 1)
        test_tube.set_specific_metabolite("so4_e", 1)
        test_tube.set_specific_metabolite("arg__L_e", 1)
        test_tube.set_specific_metabolite("ser__L_e", 1)
        test_tube.set_specific_metabolite("cu2_e", 1)
        test_tube.set_specific_metabolite("met__L_e", 1)
        test_tube.set_specific_metabolite("trp__L_e", 1)
        test_tube.set_specific_metabolite("phe__L_e", 1)
        test_tube.set_specific_metabolite("h_e", 1)
        test_tube.set_specific_metabolite("tyr__L_e", 1)
        test_tube.set_specific_metabolite("cys__L_e", 1)
        test_tube.set_specific_metabolite("ura_e", 1)
        test_tube.set_specific_metabolite("cl_e", 1)
        test_tube.set_specific_metabolite("leu__L_e", 1)
        test_tube.set_specific_metabolite("his__L_e", 1)
        test_tube.set_specific_metabolite("pro__L_e", 1)
        test_tube.set_specific_metabolite("cobalt2_e", 100)
        test_tube.set_specific_metabolite("val__L_e", 1)
        test_tube.set_specific_metabolite("thr__L_e", 1)
        test_tube.set_specific_metabolite("adn_e", 0.1)
        test_tube.set_specific_metabolite("thymd_e", 0.1)
        test_tube.set_specific_metabolite("k_e", 100)
        test_tube.set_specific_metabolite("h2s_e", 0.1)
        test_tube.set_specific_metabolite("ins_e", 0.1)
        test_tube.set_specific_metabolite("uri_e", 0.1)
        test_tube.set_specific_metabolite("mg2_e", 100)
        test_tube.set_specific_metabolite("gsn_e", 0.1)
        test_tube.set_specific_metabolite("ile__L_e", 1)
        test_tube.set_specific_metabolite("cys__L_e", 1)
        test_tube.set_specific_metabolite("skm_e", 1)
        test_tube.set_specific_metabolite("fol_e", 1)
        test_tube.set_specific_metabolite("dadn_e", 1)
        test_tube.set_specific_metabolite("lipoate_e", 0.1)
        test_tube.set_specific_metabolite("na1_e", 100)
        test_tube.set_specific_metabolite("cd2_e", 100)
        test_tube.set_specific_metabolite("aso4_e", 100)
        test_tube.set_specific_metabolite("fe2_e", 100)
        test_tube.set_specific_metabolite("fe3_e", 100)
        test_tube.set_specific_metabolite("cro4_e", 100)
        test_tube.set_specific_metabolite("nh3_c_e", 100)
        test_tube.set_specific_metabolite("pheme_e", 100)
        test_tube.set_specific_metabolite("cmp_e", 100)
        test_tube.set_specific_metabolite("ump_e", 100)
        test_tube.set_specific_metabolite("gmp_e", 100)
        test_tube.set_specific_metabolite("pydx_e", 100)
        test_tube.set_specific_metabolite("nac_e", 100)
        test_tube.set_specific_metabolite("ribflv_e", 100)
        test_tube.set_specific_metabolite("pphn_e", 100)
        test_tube.set_specific_metabolite("hxan_e", 100)
        test_tube.set_specific_metabolite("thmpp_e", 0.1)
        test_tube.set_specific_metabolite("cbl1_e", 0.1)

        # ----------------------------------------------------
        trace_metabolites = [
            'ca2_e', 'cl_e', 'cobalt2_e', 'cu2_e', 'fe2_e', 'fe3_e',
            'h_e', 'k_e', 'h2o_e', 'mg2_e', 'mn2_e', 'mobd_e',
            'na1_e', 'ni2_e', 'nh4_e', 'o2_e', 'pi_e', 'so4_e', 'zn2_e'
        ]

        for i in trace_metabolites:
            test_tube.set_specific_metabolite(i, 1000)
            test_tube.set_specific_static(i, 1000)

        # ----------------------------------------------------
        experimet = c.comets(test_tube, sim_params)
        experimet.run()

        final_models = experimet.total_biomass

        if final_models is not None:
            csv_file_name = os.path.join(csv_output_path, f"comunidad_{num}_24hr.csv")
            final_models.to_csv(csv_file_name, index=False)

            print(f" {num} registrada")
            print(final_models.to_string())
        else:
            print(f"{num} falló")


    except Exception as e:
        print(f"Falló {num}: {e}")

# %%
import cometspy as c
import cobra.io
import pandas as pd
import os
# ---------------------------
sim_params = c.params()
sim_params.set_param('maxCycles', 80)
sim_params.set_param('timeStep', 0.1)
initial_mass = [0, 0, 5e-8]   
csv_output_path = '04_resultados/rizo/biomasas/'


# ----------------------------------------------
def select_specific_files_os(folder_path, specific_filenames):

    selected_files = []
    
    for filename in specific_filenames:
        # os.path.join handles the correct slash for your OS
        full_path = os.path.join(folder_path, filename) 
        
        # Check if the file exists at that path
        if os.path.isfile(full_path):
            selected_files.append(full_path)
        else:
            print(f"Warning: '{filename}' not found.")
            
    return selected_files

folder_location = "./02_data/rizo/carveme" 


comunidad_1 = ["ST00046_prokka_carveme_lb_24.xml", "ST00154_prokka_carveme_lb_24.xml", 
               "ST00101_prokka_carveme_lb_24.xml", "ST00109_prokka_carveme_lb_24.xml", 
               "ST00042_prokka_carveme_lb_24.xml"]

comunidad_2 = ["ST00046_prokka_carveme_lb_24.xml", "ST00154_prokka_carveme_lb_24.xml", 
               "ST00101_prokka_carveme_lb_24.xml", "ST00109_prokka_carveme_lb_24.xml", 
               "ST00060_prokka_carveme_lb_24.xml"]

comunidad_3 = ["ST00046_prokka_carveme_lb_24.xml", "ST00154_prokka_carveme_lb_24.xml", 
               "ST00101_prokka_carveme_lb_24.xml", "ST00042_prokka_carveme_lb_24.xml", 
               "ST00094_prokka_carveme_lb_24.xml"]

# comunidad_4 = ["ST00046_prokka_carveme_lb.xml", "ST00154_prokka_carveme_lb.xml"
#                   , "ST00109_prokka_carveme_lb.xml", "ST00042_prokka_carveme_lb.xml", "ST00110_prokka_carveme_lb.xml"]

# comunidad_5 = ["ST00046_prokka_carveme_lb.xml", "ST00101_prokka_carveme_lb.xml"
#                   , "ST00109_prokka_carveme_lb.xml", "ST00042_prokka_carveme_lb.xml", "ST00164_prokka_carveme_lb.xml"]
# comunidad_6 = ["ST00154_prokka_carveme_lb.xml", "ST00101_prokka_carveme_lb.xml"
#                   , "ST00109_prokka_carveme_lb.xml", "ST00042_prokka_carveme_lb.xml", "ST00164_prokka_carveme_lb.xml"]
# #-------------------------------------------------
# comunidad_7 = ["ST00060_prokka_carveme_lb.xml", "ST00094_prokka_carveme_lb.xml"
#                  , "ST00110_prokka_carveme_lb.xml", "ST00164_prokka_carveme_lb.xml", "ST00143_prokka_carveme_lb.xml"]
# comunidad_8 = ["ST00042_prokka_carveme_lb.xml", "ST00094_prokka_carveme_lb.xml"
#                  , "ST00110_prokka_carveme_lb.xml", "ST00164_prokka_carveme_lb.xml", "ST00143_prokka_carveme_lb.xml"]
# comunidad_9 = ["ST00109_prokka_carveme_lb.xml", "ST00060_prokka_carveme_lb.xml"
#                  , "ST00110_prokka_carveme_lb.xml", "ST00164_prokka_carveme_lb.xml", "ST00143_prokka_carveme_lb.xml"]
# comunidad_10 = ["ST00101_prokka_carveme_lb.xml", "ST00060_prokka_carveme_lb.xml"
#                  , "ST00094_prokka_carveme_lb.xml", "ST00164_prokka_carveme_lb.xml", "ST00143_prokka_carveme_lb.xml"]
# comunidad_11 = ["ST00154_prokka_carveme_lb.xml", "ST00060_prokka_carveme_lb.xml"
#                  , "ST00094_prokka_carveme_lb.xml", "ST00110_prokka_carveme_lb.xml", "ST00164_prokka_carveme_lb.xml"]
# comunidad_12 = ["ST00046_prokka_carveme_lb.xml", "ST00060_prokka_carveme_lb.xml"
#                  , "ST00094_prokka_carveme_lb.xml", "ST00110_prokka_carveme_lb.xml", "ST00164_prokka_carveme_lb.xml"]

found_1 = select_specific_files_os(folder_location, comunidad_1)
found_2 = select_specific_files_os(folder_location, comunidad_2)
found_3 = select_specific_files_os(folder_location, comunidad_3)
# found_4 = select_specific_files_os(folder_location, comunidad_4)
# found_5 = select_specific_files_os(folder_location, comunidad_5)
# found_6 = select_specific_files_os(folder_location, comunidad_6)
# # --------------------------------------------------------------
# found_7 = select_specific_files_os(folder_location, comunidad_7)
# found_8 = select_specific_files_os(folder_location, comunidad_8)
# found_9 = select_specific_files_os(folder_location, comunidad_9)
# found_10 = select_specific_files_os(folder_location, comunidad_10)
# found_11 = select_specific_files_os(folder_location, comunidad_11)
# found_12 = select_specific_files_os(folder_location, comunidad_12)


comunidades = [found_1, found_2, found_3]

print("Found files (full paths):")

# -----------------------------------------------------------

for num, comunidad in enumerate(comunidades, start=1):
    test_tube = c.layout()

    try:
        # ----------------------------------------------------
        # Cargar todos los modelos de la comunidad
        for modelo in comunidad:
            file_name = os.path.basename(modelo)
            model_id = file_name.replace("_prokka_carveme_lb_24hr.xml", "")

            cobra_models = cobra.io.read_sbml_model(modelo)
            processed_models = c.model(cobra_models)

            processed_models.initial_pop = initial_mass
            test_tube.add_model(processed_models)

        # ----------------------------------------------------
        # Agregar metabolitos específicos (UNA sola vez)
        test_tube.set_specific_metabolite("h2o_e", 100)
        test_tube.set_specific_metabolite("o2_e", 10)
        test_tube.set_specific_metabolite("pi_e", 100)
        test_tube.set_specific_metabolite("prbamp_e", 100)
        test_tube.set_specific_metabolite("glu__L_e", 1)
        test_tube.set_specific_metabolite("mn2_e", 100)
        test_tube.set_specific_metabolite("gly_e", 1)
        test_tube.set_specific_metabolite("zn2_e", 100)
        test_tube.set_specific_metabolite("ala__L_e", 1)
        test_tube.set_specific_metabolite("lys__L_e", 1)
        test_tube.set_specific_metabolite("asp__L_e", 1)
        test_tube.set_specific_metabolite("so4_e", 1)
        test_tube.set_specific_metabolite("arg__L_e", 1)
        test_tube.set_specific_metabolite("ser__L_e", 1)
        test_tube.set_specific_metabolite("cu2_e", 1)
        test_tube.set_specific_metabolite("met__L_e", 1)
        test_tube.set_specific_metabolite("trp__L_e", 1)
        test_tube.set_specific_metabolite("phe__L_e", 1)
        test_tube.set_specific_metabolite("h_e", 1)
        test_tube.set_specific_metabolite("tyr__L_e", 1)
        test_tube.set_specific_metabolite("cys__L_e", 1)
        test_tube.set_specific_metabolite("ura_e", 1)
        test_tube.set_specific_metabolite("cl_e", 1)
        test_tube.set_specific_metabolite("leu__L_e", 1)
        test_tube.set_specific_metabolite("his__L_e", 1)
        test_tube.set_specific_metabolite("pro__L_e", 1)
        test_tube.set_specific_metabolite("cobalt2_e", 100)
        test_tube.set_specific_metabolite("val__L_e", 1)
        test_tube.set_specific_metabolite("thr__L_e", 1)
        test_tube.set_specific_metabolite("adn_e", 0.1)
        test_tube.set_specific_metabolite("thymd_e", 0.1)
        test_tube.set_specific_metabolite("k_e", 100)
        test_tube.set_specific_metabolite("h2s_e", 0.1)
        test_tube.set_specific_metabolite("ins_e", 0.1)
        test_tube.set_specific_metabolite("uri_e", 0.1)
        test_tube.set_specific_metabolite("mg2_e", 100)
        test_tube.set_specific_metabolite("gsn_e", 0.1)
        test_tube.set_specific_metabolite("ile__L_e", 1)
        test_tube.set_specific_metabolite("cys__L_e", 1)
        test_tube.set_specific_metabolite("skm_e", 1)
        test_tube.set_specific_metabolite("fol_e", 1)
        test_tube.set_specific_metabolite("dadn_e", 1)
        test_tube.set_specific_metabolite("lipoate_e", 0.1)
        test_tube.set_specific_metabolite("na1_e", 100)
        test_tube.set_specific_metabolite("cd2_e", 100)
        test_tube.set_specific_metabolite("aso4_e", 100)
        test_tube.set_specific_metabolite("fe2_e", 100)
        test_tube.set_specific_metabolite("fe3_e", 100)
        test_tube.set_specific_metabolite("cro4_e", 100)
        test_tube.set_specific_metabolite("nh3_c_e", 100)
        test_tube.set_specific_metabolite("pheme_e", 100)
        test_tube.set_specific_metabolite("cmp_e", 100)
        test_tube.set_specific_metabolite("ump_e", 100)
        test_tube.set_specific_metabolite("gmp_e", 100)
        test_tube.set_specific_metabolite("pydx_e", 100)
        test_tube.set_specific_metabolite("nac_e", 100)
        test_tube.set_specific_metabolite("ribflv_e", 100)
        test_tube.set_specific_metabolite("pphn_e", 100)
        test_tube.set_specific_metabolite("hxan_e", 100)
        test_tube.set_specific_metabolite("thmpp_e", 0.1)
        test_tube.set_specific_metabolite("cbl1_e", 0.1)

        # ----------------------------------------------------
        trace_metabolites = [
            'ca2_e', 'cl_e', 'cobalt2_e', 'cu2_e', 'fe2_e', 'fe3_e',
            'h_e', 'k_e', 'h2o_e', 'mg2_e', 'mn2_e', 'mobd_e',
            'na1_e', 'ni2_e', 'nh4_e', 'o2_e', 'pi_e', 'so4_e', 'zn2_e'
        ]

        for i in trace_metabolites:
            test_tube.set_specific_metabolite(i, 1000)
            test_tube.set_specific_static(i, 1000)

        # ----------------------------------------------------
        experimet = c.comets(test_tube, sim_params)
        experimet.run()

        final_models = experimet.total_biomass

        if final_models is not None:
            csv_file_name = os.path.join(csv_output_path, f"comunidad_{num}.csv")
            final_models.to_csv(csv_file_name, index=False)

            print(f" {num} registrada")
            print(final_models.to_string())
        else:
            print(f"{num} falló")


    except Exception as e:
        print(f"Falló {num}: {e}")
